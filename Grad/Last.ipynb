# %%
import json
from pathlib import Path
import pandas as pd
import numpy as np
import csv
p = Path(r'E:/MSA/Fall 2023/Big Data/GP/AutoMD-webCrawler-master/JSON/webPages_en_pretty_repaired.json')

# %%
with p.open('r', encoding='utf-8') as f:
    json_text = json.loads(f.read())

# %%
parse_json_text=[]

news_df=pd.DataFrame(json_text['childWebPageList'])
news_df.head(4)

pd.DataFrame(news_df).head()
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 1  If you know what is wrong, start by selecting it:
#
#                                     childWebPageList problemList  \
# 0  [{'title': '', 'aidPair': {'key': 'Smell - I s...          []
# 1  [{'title': '', 'aidPair': {'key': 'Engine', 'v...          []
#
#                   aidPair
# 0                     NaN
# 1  {'key': '', 'val': ''}

# %%
news_df.loc[:,['title','childWebPageList']].head()
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 1  If you know what is wrong, start by selecting it:
#
#                                     childWebPageList
# 0  [{'title': '', 'aidPair': {'key': 'Smell - I s...
# 1  [{'title': '', 'aidPair': {'key': 'Engine', 'v...

# %%
mod_df=news_df.loc[:,['title','childWebPageList']]

for i in mod_df.columns:
    mod_df=mod_df.explode(i)
mod_df
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 0  If you're not sure what the problem is, start ...
# 0  If you're not sure what the problem is, start ...
# 0  If you're not sure what the problem is, start ...
# 0  If you're not sure what the problem is, start ...
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
# 1  If you know what is wrong, start by selecting it:
#
# ...

# %%
flat_dct=pd.json_normalize(json.loads(mod_df.\
                                to_json(orient="records")))
flat_dct.head(len(flat_dct))
# Out:
#                                                 title childWebPageList.title  \
# 0   If you're not sure what the problem is, start ...
# 1   If you're not sure what the problem is, start ...
# 2   If you're not sure what the problem is, start ...
# 3   If you're not sure what the problem is, start ...
# 4   If you're not sure what the problem is, start ...
# 5   If you know what is wrong, start by selecting it:
# 6   If you know what is wrong, start by selecting it:
# 7   If you know what is wrong, start by selecting it:
# 8   If you know what is wrong, start by selecting it:
# 9   If you know what is wrong, start by selecting it:
# 10  If you know what is wrong, start by selecting it:
# 11  If you know what is wrong, start by selecting it:
# 12  If you know what is wrong, start by selecting it:
# 13  If you know what is wrong, start by selecting it:
# 14  If you know what is wrong, start by selecting it:
# 15  If you know what is wrong, start by selecting it:
# ...

# %%
mod_df2=flat_dct.loc[:,['title','childWebPageList.aidPair.key','childWebPageList.aidPair.val','childWebPageList.childWebPageList']]

for i in mod_df2.columns:
    mod_df2=mod_df2.explode(i)
mod_df2
# Out:
#                                                 title  \
# 0   If you're not sure what the problem is, start ...
# 1   If you're not sure what the problem is, start ...
# 2   If you're not sure what the problem is, start ...
# 3   If you're not sure what the problem is, start ...
# 4   If you're not sure what the problem is, start ...
# 5   If you know what is wrong, start by selecting it:
# 6   If you know what is wrong, start by selecting it:
# 7   If you know what is wrong, start by selecting it:
# 8   If you know what is wrong, start by selecting it:
# 9   If you know what is wrong, start by selecting it:
# 10  If you know what is wrong, start by selecting it:
# 11  If you know what is wrong, start by selecting it:
# 12  If you know what is wrong, start by selecting it:
# 13  If you know what is wrong, start by selecting it:
# 14  If you know what is wrong, start by selecting it:
# 15  If you know what is wrong, start by selecting it:
# ...

# %%
flat_dc2t=pd.json_normalize(json.loads(mod_df2.\
                                to_json(orient="records")))
flat_dc2t.head(10)
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 1  If you're not sure what the problem is, start ...
# 2  If you're not sure what the problem is, start ...
# 3  If you're not sure what the problem is, start ...
# 4  If you're not sure what the problem is, start ...
# 5  If you know what is wrong, start by selecting it:
# 6  If you know what is wrong, start by selecting it:
# 7  If you know what is wrong, start by selecting it:
# 8  If you know what is wrong, start by selecting it:
# 9  If you know what is wrong, start by selecting it:
#
#                         childWebPageList.aidPair.key  \
# 0  Smell - I smell it (i.e. gasoline, rotten eggs...
# 1  Feel - I feel it (i.e. hesitation, shimmy, vib...
# 2                              Ugh! - It won't start
# 3  Hear - I hear it (i.e. a rattle, a knock, or a...
# 4  See - I see it (i.e. oil leak, warning light, ...
# 5                                             Engine
# ...

# %%
mod_df3=flat_dc2t.loc[:,['title','childWebPageList.aidPair.key','childWebPageList.aidPair.val','childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.problemList']]

for i in mod_df3.columns:
    mod_df3=mod_df3.explode(i)
mod_df3
# Out:
#                                                 title  \
# 0   If you're not sure what the problem is, start ...
# 0   If you're not sure what the problem is, start ...
# 0   If you're not sure what the problem is, start ...
# 0   If you're not sure what the problem is, start ...
# 0   If you're not sure what the problem is, start ...
# ..                                                ...
# 15  If you know what is wrong, start by selecting it:
# 15  If you know what is wrong, start by selecting it:
# 16  If you know what is wrong, start by selecting it:
# 16  If you know what is wrong, start by selecting it:
# 16  If you know what is wrong, start by selecting it:
#
#                          childWebPageList.aidPair.key  \
# 0   Smell - I smell it (i.e. gasoline, rotten eggs...
# 0   Smell - I smell it (i.e. gasoline, rotten eggs...
# 0   Smell - I smell it (i.e. gasoline, rotten eggs...
# 0   Smell - I smell it (i.e. gasoline, rotten eggs...
# ...

# %%
flat_dct3=pd.json_normalize(json.loads(mod_df3.\
                                to_json(orient="records")))
flat_dct3.head(2)
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 1  If you're not sure what the problem is, start ...
#
#                         childWebPageList.aidPair.key  \
# 0  Smell - I smell it (i.e. gasoline, rotten eggs...
# 1  Smell - I smell it (i.e. gasoline, rotten eggs...
#
#   childWebPageList.aidPair.val childWebPageList.childWebPageList.title  \
# 0                          388                 What odor do you smell?
# 1                          388                 What odor do you smell?
#
#   childWebPageList.childWebPageList.aidPair.val  \
# 0                                           388
# 1                                           388
#
#   childWebPageList.childWebPageList.childWebPageList.title  \
# 0
# 1
#
#   childWebPageList.childWebPageList.childWebPageList.aidPair.key  \
# 0                                        Rotten eggs
# 1                                           Gasoline
#
# ...

# %%
mod_df4=flat_dct3.loc[:,['title','childWebPageList.aidPair.key','childWebPageList.aidPair.val','childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.problemList']]

for i in mod_df4.columns:
    mod_df4=mod_df4.explode(i)
mod_df4.head(10)
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 0  If you're not sure what the problem is, start ...
# 1  If you're not sure what the problem is, start ...
# 2  If you're not sure what the problem is, start ...
# 3  If you're not sure what the problem is, start ...
# 4  If you're not sure what the problem is, start ...
# 5  If you're not sure what the problem is, start ...
# 6  If you're not sure what the problem is, start ...
# 6  If you're not sure what the problem is, start ...
# 7  If you're not sure what the problem is, start ...
#
#                         childWebPageList.aidPair.key  \
# 0  Smell - I smell it (i.e. gasoline, rotten eggs...
# 0  Smell - I smell it (i.e. gasoline, rotten eggs...
# 1  Smell - I smell it (i.e. gasoline, rotten eggs...
# 2  Smell - I smell it (i.e. gasoline, rotten eggs...
# 3  Smell - I smell it (i.e. gasoline, rotten eggs...
# 4  Smell - I smell it (i.e. gasoline, rotten eggs...
# ...

# %%
flat_dct4=pd.json_normalize(json.loads(mod_df4.\
                                to_json(orient="records")))
flat_dct4.head(100)
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 1  If you're not sure what the problem is, start ...
# 2  If you're not sure what the problem is, start ...
# 3  If you're not sure what the problem is, start ...
# 4  If you're not sure what the problem is, start ...
#
#                         childWebPageList.aidPair.key  \
# 0  Smell - I smell it (i.e. gasoline, rotten eggs...
# 1  Smell - I smell it (i.e. gasoline, rotten eggs...
# 2  Smell - I smell it (i.e. gasoline, rotten eggs...
# 3  Smell - I smell it (i.e. gasoline, rotten eggs...
# 4  Smell - I smell it (i.e. gasoline, rotten eggs...
#
#   childWebPageList.aidPair.val childWebPageList.childWebPageList.title  \
# 0                          388                 What odor do you smell?
# 1                          388                 What odor do you smell?
# 2                          388                 What odor do you smell?
# ...

# %%
mod_df5=flat_dct4.loc[:,['title','childWebPageList.aidPair.key','childWebPageList.aidPair.val','childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList']]
for i in mod_df5.columns:
    mod_df5=mod_df5.explode(i)

# %%
flat_dct5=pd.json_normalize(json.loads(mod_df5.\
                                to_json(orient="records")))
flat_dct5.head(11)
# Out:
#                                                 title  \
# 0   If you're not sure what the problem is, start ...
# 1   If you're not sure what the problem is, start ...
# 2   If you're not sure what the problem is, start ...
# 3   If you're not sure what the problem is, start ...
# 4   If you're not sure what the problem is, start ...
# 5   If you're not sure what the problem is, start ...
# 6   If you're not sure what the problem is, start ...
# 7   If you're not sure what the problem is, start ...
# 8   If you're not sure what the problem is, start ...
# 9   If you're not sure what the problem is, start ...
# 10  If you're not sure what the problem is, start ...
#
#                          childWebPageList.aidPair.key  \
# 0   Smell - I smell it (i.e. gasoline, rotten eggs...
# 1   Smell - I smell it (i.e. gasoline, rotten eggs...
# 2   Smell - I smell it (i.e. gasoline, rotten eggs...
# 3   Smell - I smell it (i.e. gasoline, rotten eggs...
# ...

# %%
flat_dct5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845 entries, 0 to 844
# Data columns (total 20 columns):
#  #   Column                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                 --------------  -----
#  0   title                                                                                                  845 non-null    object
#  1   childWebPageList.aidPair.key                                                                           845 non-null    object
#  2   childWebPageList.aidPair.val                                                                           845 non-null    object
#  3   childWebPageList.childWebPageList.title                                                                845 non-null    object
# ...

# %%
flat_dct5.to_csv("ofc.csv")

# %%
mod_df6=flat_dct5.loc[:,['title','childWebPageList.aidPair.key','childWebPageList.aidPair.val','childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList']]
   
for i in mod_df6.columns:
    mod_df6=mod_df6.explode(i)

# %%
flat_dct6=pd.json_normalize(json.loads(mod_df6.\
                                to_json(orient="records")))
flat_dct6.head(10)
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 1  If you're not sure what the problem is, start ...
# 2  If you're not sure what the problem is, start ...
# 3  If you're not sure what the problem is, start ...
# 4  If you're not sure what the problem is, start ...
# 5  If you're not sure what the problem is, start ...
# 6  If you're not sure what the problem is, start ...
# 7  If you're not sure what the problem is, start ...
# 8  If you're not sure what the problem is, start ...
# 9  If you're not sure what the problem is, start ...
#
#                         childWebPageList.aidPair.key  \
# 0  Smell - I smell it (i.e. gasoline, rotten eggs...
# 1  Smell - I smell it (i.e. gasoline, rotten eggs...
# 2  Smell - I smell it (i.e. gasoline, rotten eggs...
# 3  Smell - I smell it (i.e. gasoline, rotten eggs...
# 4  Smell - I smell it (i.e. gasoline, rotten eggs...
# 5  Smell - I smell it (i.e. gasoline, rotten eggs...
# ...

# %%
flat_dct6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 890 entries, 0 to 889
# Data columns (total 26 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   title                                                                                                                   890 non-null    object
#  1   childWebPageList.aidPair.key                                                                                            890 non-null    object
#  2   childWebPageList.aidPair.val                                                                                            890 non-null    object
# ...

# %%
flat_dct6.to_csv('maybe.csv')

# %%
mod_df7=flat_dct6.loc[:,['title','childWebPageList.aidPair.key','childWebPageList.aidPair.val','childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList']]

for i in mod_df7.columns:
    mod_df7=mod_df7.explode(i)

# %%
flat_dct7=pd.json_normalize(json.loads(mod_df7.\
                                to_json(orient="records")))
flat_dct7.head(2)
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 1  If you're not sure what the problem is, start ...
#
#                         childWebPageList.aidPair.key  \
# 0  Smell - I smell it (i.e. gasoline, rotten eggs...
# 1  Smell - I smell it (i.e. gasoline, rotten eggs...
#
#   childWebPageList.aidPair.val childWebPageList.childWebPageList.title  \
# 0                          388                 What odor do you smell?
# 1                          388                 What odor do you smell?
#
#   childWebPageList.childWebPageList.aidPair.val  \
# 0                                           388
# 1                                           388
#
#   childWebPageList.childWebPageList.childWebPageList.aidPair.key  \
# 0                                        Rotten eggs
# 1                                        Rotten eggs
#
#   childWebPageList.childWebPageList.childWebPageList.aidPair.val  \
# ...

# %%
flat_dct7.to_csv('Last4.csv')

# %%
mod_df8=flat_dct7.loc[:,['title','childWebPageList.aidPair.key','childWebPageList.aidPair.val','childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList']]

for i in mod_df8.columns:
    mod_df8=mod_df8.explode(i)

# %%
flat_dct8=pd.json_normalize(json.loads(mod_df8.\
                                to_json(orient="records")))
flat_dct8.head(2)
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 1  If you're not sure what the problem is, start ...
#
#                         childWebPageList.aidPair.key  \
# 0  Smell - I smell it (i.e. gasoline, rotten eggs...
# 1  Smell - I smell it (i.e. gasoline, rotten eggs...
#
#   childWebPageList.aidPair.val childWebPageList.childWebPageList.title  \
# 0                          388                 What odor do you smell?
# 1                          388                 What odor do you smell?
#
#   childWebPageList.childWebPageList.aidPair.val  \
# 0                                           388
# 1                                           388
#
#   childWebPageList.childWebPageList.childWebPageList.aidPair.key  \
# 0                                        Rotten eggs
# 1                                        Rotten eggs
#
#   childWebPageList.childWebPageList.childWebPageList.aidPair.val  \
# ...

# %%
flat_dct9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1968 entries, 0 to 1967
# Data columns (total 42 columns):
#  #   Column                                                                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                                                                     --------------  -----
#  0   title                                                                                                                                                                      1968 non-null   object
#  1   childWebPageList.aidPair.key                                                                                                                                               1968 non-null   object
# ...

# %%
mod_df9=flat_dct8.loc[:,['title','childWebPageList.aidPair.key','childWebPageList.aidPair.val','childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList']]
for i in mod_df9.columns:
    mod_df9=mod_df9.explode(i)

# %%
flat_dct9=pd.json_normalize(json.loads(mod_df9.\
                                to_json(orient="records")))
flat_dct9.head(2)
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 1  If you're not sure what the problem is, start ...
#
#                         childWebPageList.aidPair.key  \
# 0  Smell - I smell it (i.e. gasoline, rotten eggs...
# 1  Smell - I smell it (i.e. gasoline, rotten eggs...
#
#   childWebPageList.aidPair.val childWebPageList.childWebPageList.title  \
# 0                          388                 What odor do you smell?
# 1                          388                 What odor do you smell?
#
#   childWebPageList.childWebPageList.aidPair.val  \
# 0                                           388
# 1                                           388
#
#   childWebPageList.childWebPageList.childWebPageList.aidPair.key  \
# 0                                        Rotten eggs
# 1                                        Rotten eggs
#
#   childWebPageList.childWebPageList.childWebPageList.aidPair.val  \
# ...

# %%
mod_df10=flat_dct9.loc[:,['title','childWebPageList.aidPair.key','childWebPageList.aidPair.val','childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList']]
for i in mod_df10.columns:
    mod_df10=mod_df10.explode(i)

# %%
flat_dct10=pd.json_normalize(json.loads(mod_df10.\
                                to_json(orient="records")))
flat_dct10.head(2)
# Out:
#                                                title  \
# 0  If you're not sure what the problem is, start ...
# 1  If you're not sure what the problem is, start ...
#
#                         childWebPageList.aidPair.key  \
# 0  Smell - I smell it (i.e. gasoline, rotten eggs...
# 1  Smell - I smell it (i.e. gasoline, rotten eggs...
#
#   childWebPageList.aidPair.val childWebPageList.childWebPageList.title  \
# 0                          388                 What odor do you smell?
# 1                          388                 What odor do you smell?
#
#   childWebPageList.childWebPageList.aidPair.val  \
# 0                                           388
# 1                                           388
#
#   childWebPageList.childWebPageList.childWebPageList.aidPair.key  \
# 0                                        Rotten eggs
# 1                                        Rotten eggs
#
#   childWebPageList.childWebPageList.childWebPageList.aidPair.val  \
# ...

# %%
mod_df11=flat_dct10.loc[:,['title','childWebPageList.aidPair.key','childWebPageList.aidPair.val','childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.key','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.aidPair.val','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.title','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.description','childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.childWebPageList.problemList.inspectionList']]
for i in mod_df11.columns:
    mod_df11=mod_df11.explode(i)

# %%
flat_dct11=pd.json_normalize(json.loads(mod_df11.\
                                to_json(orient="records")))
flat_dct11.head(2)
flat_dct11.to_csv('ActiveFinal3.csv')
